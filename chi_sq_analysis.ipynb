# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load data
airq_asthma_df = pd.read_csv('data/airq_FNOS_asthma.csv')

# %%
airq_asthma_df.head()
# Out:
#    year        borough             geo_place_name  mean_fpm  mean_no  \
# 0  2011       brooklyn                 greenpoint     11.51    25.84
# 1  2013  staten island  south beach - tottenville      7.82    11.51
# 2  2014  staten island  south beach - tottenville      8.20    12.59
# 3  2009  staten island  south beach - tottenville      9.63    14.71
# 4  2012  staten island  south beach - tottenville      8.28    12.47
#
#    ozone mean (ppb)  mean_so2  ed_annual_adult_rate_per10k
# 0              31.6      1.95                         65.4
# 1              32.7      0.73                         33.9
# 2              32.0      0.22                         32.4
# 3              27.8      1.01                         36.6
# 4              35.3      0.39                         44.9

# %%
#describe data
airq_asthma_df.describe()
# Out:
#               year    mean_fpm     mean_no  ozone mean (ppb)    mean_so2  \
# count   252.000000  252.000000  252.000000        252.000000  252.000000
# mean   2011.500000    9.973452   23.077976         30.259127    2.507540
# std       1.711224    1.367010    5.520205          4.001060    1.970882
# min    2009.000000    7.360000   11.510000         16.100000    0.220000
# 25%    2010.000000    8.970000   19.417500         27.575000    1.032500
# 50%    2011.500000    9.810000   22.345000         31.100000    1.900000
# 75%    2013.000000   10.780000   25.752500         33.200000    3.362500
# max    2014.000000   15.030000   43.320000         40.300000   10.510000
#
#        ed_annual_adult_rate_per10k
# count                   252.000000
# mean                    111.551190
# std                      90.307775
# min                      11.700000
# 25%                      45.800000
# 50%                      74.300000
# 75%                     152.575000
# max                     375.400000

# %%
#create new column from copy of 'ed_annual_adult_rate_per10k'
airq_asthma_df['asthma_rate_category'] = airq_asthma_df['ed_annual_adult_rate_per10k'].copy()

# %%
airq_asthma_df.head()
# Out:
#    year        borough             geo_place_name  mean_fpm  mean_no  \
# 0  2011       brooklyn                 greenpoint     11.51    25.84
# 1  2013  staten island  south beach - tottenville      7.82    11.51
# 2  2014  staten island  south beach - tottenville      8.20    12.59
# 3  2009  staten island  south beach - tottenville      9.63    14.71
# 4  2012  staten island  south beach - tottenville      8.28    12.47
#
#    ozone mean (ppb)  mean_so2  ed_annual_adult_rate_per10k  \
# 0              31.6      1.95                         65.4
# 1              32.7      0.73                         33.9
# 2              32.0      0.22                         32.4
# 3              27.8      1.01                         36.6
# 4              35.3      0.39                         44.9
#
#    asthma_rate_category
# 0                  65.4
# 1                  33.9
# 2                  32.4
# 3                  36.6
# 4                  44.9

# %%
#transform asthma rates to categorical variable

asthma_list =[]
def category_map (column):
    for rate in column: 
        if rate>=0.0 and rate<126.0: 
            asthma_list.append('low')
        elif rate>=126.0 and rate<252.0: 
            asthma_list.append('medium')
        else: 
            asthma_list.append('high')
                    
    return asthma_list

# %%
#apply function to transform column
asthma_rate_series=category_map(airq_asthma_df['asthma_rate_category'])

# %%
len(asthma_rate_series)
# Out:
# 252

# %%
airq_asthma_df['asthma_rate_category'] = asthma_rate_series

# %%
airq_asthma_df.head()
# Out:
#    year        borough             geo_place_name  mean_fpm  mean_no  \
# 0  2011       brooklyn                 greenpoint     11.51    25.84
# 1  2013  staten island  south beach - tottenville      7.82    11.51
# 2  2014  staten island  south beach - tottenville      8.20    12.59
# 3  2009  staten island  south beach - tottenville      9.63    14.71
# 4  2012  staten island  south beach - tottenville      8.28    12.47
#
#    ozone mean (ppb)  mean_so2  ed_annual_adult_rate_per10k  \
# 0              31.6      1.95                         65.4
# 1              32.7      0.73                         33.9
# 2              32.0      0.22                         32.4
# 3              27.8      1.01                         36.6
# 4              35.3      0.39                         44.9
#
#   asthma_rate_category
# 0                  low
# 1                  low
# 2                  low
# 3                  low
# 4                  low

# %%
#create df with only borough and asthma rate category
borough_rate_df = airq_asthma_df[['borough', 'asthma_rate_category']]

# %%
borough_rate_df.head()
# Out:
#          borough asthma_rate_category
# 0       brooklyn                  low
# 1  staten island                  low
# 2  staten island                  low
# 3  staten island                  low
# 4  staten island                  low

# %%
#find frequencies of each category
borough_rate_freq = borough_rate_df.groupby(['borough', 'asthma_rate_category']).size().reset_index(name='count')

# %%
borough_rate_freq
# Out:
#           borough asthma_rate_category  count
# 0           bronx                 high     18
# 1           bronx                  low      9
# 2           bronx               medium     15
# 3        brooklyn                 high      1
# 4        brooklyn                  low     44
# 5        brooklyn               medium     21
# 6       manhattan                 high     12
# 7       manhattan                  low     48
# 8          queens                  low     59
# 9          queens               medium      1
# 10  staten island                  low     18
# 11  staten island               medium      6

# %%
#create pivot table for chi square
borough_rate_pivot = pd.pivot_table(borough_rate_freq, index = 'borough', values='count',
                    columns='asthma_rate_category', fill_value =0)

# %%
borough_rate_pivot
# Out:
# asthma_rate_category  high  low  medium
# borough
# bronx                   18    9      15
# brooklyn                 1   44      21
# manhattan               12   48       0
# queens                   0   59       1
# staten island            0   18       6

# %%
from scipy.stats import chi2_contingency, ttest_ind

# %%
#perform chi sq
chi2, p, dof, ex = chi2_contingency(borough_rate_pivot)
print('verification_status: p-value of chisquare test =', p)
# Out:
# verification_status: p-value of chisquare test = 4.4814008582364374e-20

# %% [markdown]
# #### Chi sq is significant indicating that we can reject null hypothesis that asthma rates among all boroughs are the same.

# %%
borough_rate_transpose = borough_rate_pivot.T

# %%
borough_rate_transpose
# Out:
# borough               bronx  brooklyn  manhattan  queens  staten island
# asthma_rate_category
# high                     18         1         12       0              0
# low                       9        44         48      59             18
# medium                   15        21          0       1              6

# %%
chi2, p, dof, ex = chi2_contingency(borough_rate_transpose)
print('verification_status: p-value of chisquare test =', p)
# Out:
# verification_status: p-value of chisquare test = 4.4814008582364374e-20
